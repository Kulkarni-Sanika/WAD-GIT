# %%
#importing dependencies
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Reading dataset
df=pd.read_csv("/content/drive/MyDrive/facebook.csv",sep=",")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape #n.o of rows and columns
# Out:
# (500, 19)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.isnull().sum() #counting number of null values
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
dv=df.duplicated().sum() #calculating number of duplicate values 
print("Number of duplicate values are:",dv)
# Out:
# Number of duplicate values are: 0

# %%
df.dtypes # finding data type
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
#Replacing null values with mean 
mean=df[['Paid','like','share']].mean()
df[['Paid','like','share']]=df[['Paid','like','share']].fillna(mean)

# %%
df.describe().T
# Out:
#                                                     count           mean  \
# Page total likes                                    500.0  123194.176000
# Category                                            500.0       1.880000
# Post Month                                          500.0       7.038000
# Post Weekday                                        500.0       4.150000
# Post Hour                                           500.0       7.840000
# Paid                                                500.0       0.278557
# Lifetime Post Total Reach                           500.0   13903.360000
# Lifetime Post Total Impressions                     500.0   29585.948000
# Lifetime Engaged Users                              500.0     920.344000
# Lifetime Post Consumers                             500.0     798.772000
# Lifetime Post Consumptions                          500.0    1415.130000
# Lifetime Post Impressions by people who have li...  500.0   16766.376000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 500 non-null    float64
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.corr()
# Out:
# <ipython-input-32-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                     Page total likes  \
# Page total likes                                            1.000000
# Category                                                   -0.091142
# Post Month                                                  0.941192
# Post Weekday                                               -0.005401
# Post Hour                                                  -0.143807
# Paid                                                        0.005306
# Lifetime Post Total Reach                                  -0.083245
# Lifetime Post Total Impressions                            -0.102540
# Lifetime Engaged Users                                     -0.111922
# ...

# %%
#PLOTTING HEATMAP
plt.figure(figsize=(11,9))
sns.heatmap(df.corr(),annot=True,fmt=".2f")
# Out:
# <ipython-input-33-f4d79120c069>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt=".2f")
# <Axes: >

# %%
#Displaying type count
type_c=df['Type'].value_counts()
labels=['Photo','Status','Link','Video']
type_c
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
df['Type'].unique() #Displaying unique elements
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %% [markdown]
# **PLOTS**

# %%
df['Type'].value_counts().plot(kind="bar",color="red")
# Out:
# <Axes: >

# %%
plt.pie(type_c,labels=labels)
plt.legend()

# %%
#Displaying category count
category_count=df['Category'].value_counts()
label=['Category 1','Category 2','Category 3']
category_count
# Out:
# 1    215
# 3    155
# 2    130
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.pie(category_count,labels=label)
plt.legend()

# %%
#displaying paid count
paid_count=df['Paid'].value_counts()
paid_count
# Out:
# 0.000000    360
# 1.000000    139
# 0.278557      1
# Name: Paid, dtype: int64

# %%
df['Paid'].value_counts().plot(kind="bar",color="yellow")
# Out:
# <Axes: >

# %%
#Histogram

# %%
sns.histplot(data=df,x="Post Month",color='red')
# Out:
# <Axes: xlabel='Post Month', ylabel='Count'>

# %%
sns.displot(data=df,x="Post Hour")

# %%
sns.displot(data=df,x="Post Weekday")

# %%
sns.barplot(x='Post Month', y='Total Interactions', data=df)
# Out:
# <Axes: xlabel='Post Month', ylabel='Total Interactions'>

# %% [markdown]
# **# Subsets by Columns**

# %%
x1=df[['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
       'Post Hour', 'Paid', 'Lifetime Post Total Reach',
       'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
       'Lifetime Post Consumers', 'Lifetime Post Consumptions']]
x1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
y1=df[['Lifetime Post Impressions by people who have liked your Page',
       'Lifetime Post reach by people who like your Page',
       'Lifetime People who have liked your Page and engaged with your post',
       'comment', 'like', 'share', 'Total Interactions']]
y1
# Out:
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# ...

# %%
cx2=df.loc[0:,['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
       'Post Hour', 'Paid', 'Lifetime Post Total Reach',
       'Lifetime Post Total Impressions', 'Lifetime Engaged Users']]
cx2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
cy2=df.loc[0:,['Lifetime Post Impressions by people who have liked your Page',
       'Lifetime Post reach by people who like your Page',
       'Lifetime People who have liked your Page and engaged with your post',
       'comment', 'like', 'share', 'Total Interactions','Lifetime Post Consumers', 'Lifetime Post Consumptions']]
cy2
# Out:
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# ...

# %%
x3=df.iloc[:,0:10]
x3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
y3=df.iloc[:,10:]
y3
# Out:
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 0                        109                         159
# 1                       1361                        1674
# 2                        113                         154
# 3                        790                        1119
# 4                        410                         580
# ..                       ...                         ...
# 495                      708                         985
# 496                      508                         687
# 497                      572                         795
# 498                      574                         832
# 499                      524                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# ...

# %% [markdown]
# # Subsets by Rows

# %%
r1=df.loc[0:299]
r1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 295            125612   Photo         1           6             2          2
# 296            125612   Photo         3           6             1         14
# 297            125612   Photo         3           6             1          3
# 298            125612   Photo         2           6             7         11
# 299            124940   Photo         1           6             7          4
#
# ...

# %%
r11=df.loc[300:]
r11
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 300            124940  Photo         2           6             6          9
# 301            124940  Photo         3           6             6          2
# 302            124940  Photo         1           6             5         13
# 303            124940  Photo         3           6             5          3
# 304            124940  Photo         1           6             4         12
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
r2p1=df.iloc[0:350,:]
r2p1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 345            117764   Photo         3           5             7         13
# 346            117764   Photo         3           5             7          2
# 347            117764   Photo         3           5             6         13
# 348            117764   Photo         3           5             6          8
# 349            117764   Photo         3           5             5         13
#
# ...

# %%
r2p2=df.iloc[350:,:]
r2p2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 350            116435   Photo         2           5             5          9
# 351            116435   Photo         3           5             4         13
# 352            116435  Status         1           5             4          3
# 353            116435   Photo         3           5             3          7
# 354            116435   Photo         2           5             2         14
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
from sklearn.model_selection import train_test_split
X=df.iloc[:,0:10]
Y=df.iloc[:,10:]
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20, random_state=0)

# %%
X_train
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 107            136736  Status         2          10             1          4
# 336            119198   Photo         3           5             6         14
# 71             137893   Video         1          11             5          3
# 474             91009   Photo         1           2             1         12
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 323            123047   Photo         3           6             1         10
# 192            133679   Photo         2           8             1          4
# 117            136642   Photo         1          10             7         11
# 47             138353    Link         1          12             3          2
# 172            135195  Status         2           9             1         10
#
# ...

# %%
Y_train
# Out:
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 107                     1032                        1512
# 336                      479                         604
# 71                      1735                        2331
# 474                     1479                        1837
# 6                        265                         364
# ..                       ...                         ...
# 323                     1334                        1850
# 192                      324                         402
# 117                      298                         331
# 47                        83                         126
# 172                     4754                        5906
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 107                                              16018
# 336                                               3353
# 71                                               59658
# ...

# %% [markdown]
# **# Data Merging**

# %%
c1=df.iloc[:,0:10]
c2=df.iloc[:,9:]
merged_d=c1.merge(c2,how="right")
merged_d
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 701            135195   Photo         2           9             5          2
# 702             81370   Photo         3           1             4         11
# 703            125612   Photo         3           6             1          3
# 704            111620   Photo         3           4             3          7
# 705             81370   Photo         2           1             4          4
#
# ...

# %%
r1=df.iloc[0:200,:]
r2=df.iloc[200:,:]
merged_d2=pd.concat([r1,r2])
merged_d2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Sorting column values

# %%
df.sort_values(by="like",ascending=True)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 76             137893  Photo         1          11             3          2
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# ..                ...    ...       ...         ...           ...        ...
# 3              139441  Photo         2          12             2         10
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
#
# ...

# %%
df.sort_values(by="comment",ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
# ..                ...    ...       ...         ...           ...        ...
# 332            119198  Photo         3           5             2         12
# 333            119198  Photo         3           5             2          1
# 111            136736  Photo         1          10             6          8
# 103            137020  Photo         1          10             3          4
# 499             81370  Photo         2           1             4          4
#
# ...

# %% [markdown]
# ** Data Transposing **

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# **# Shape and Reshape the Data**

# %%
n1=df.melt(id_vars=['Type'],value_vars=['share'])
n1
# Out:
#        Type variable  value
# 0     Photo    share   17.0
# 1    Status    share   29.0
# 2     Photo    share   14.0
# 3     Photo    share  147.0
# 4     Photo    share   49.0
# ..      ...      ...    ...
# 495   Photo    share   26.0
# 496   Photo    share   22.0
# 497   Photo    share   18.0
# 498   Photo    share   38.0
# 499   Photo    share   28.0
#
# [500 rows x 3 columns]

# %%
n2=df.melt(id_vars=['like'],value_vars=['Type'])
n2
# Out:
#        like variable   value
# 0      79.0     Type   Photo
# 1     130.0     Type  Status
# 2      66.0     Type   Photo
# 3    1572.0     Type   Photo
# 4     325.0     Type   Photo
# ..      ...      ...     ...
# 495    53.0     Type   Photo
# 496    53.0     Type   Photo
# 497    93.0     Type   Photo
# 498    91.0     Type   Photo
# 499    91.0     Type   Photo
#
# [500 rows x 3 columns]

# %%
t=pd.pivot_table(df,values=['Type','share'],index=['like','comment'])
t
# Out:
# <ipython-input-76-35dcbd702795>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   t=pd.pivot_table(df,values=['Type','share'],index=['like','comment'])
#                     share
# like   comment
# 0.0    0          0.00000
# 1.0    1          2.00000
# 2.0    0          9.08871
# 3.0    0          0.00000
#        1          2.00000
# ...                   ...
# 1572.0 58       147.00000
# 1622.0 144      208.00000
# 1639.0 45       122.00000
# 1998.0 51       128.00000
# 5172.0 372      790.00000
#
# [430 rows x 1 columns]
